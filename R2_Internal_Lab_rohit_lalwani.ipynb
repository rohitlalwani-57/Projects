# %% [markdown]
# # K nearest neighbors

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x, y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h: X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Overview
#
# 1. Read the problem statement.
#
# 2. Get the dataset.
#
# 3. Explore the dataset.
#
# 4. Pre-processing of dataset.
#
# 5. Visualization
#
# 6. Transform the dataset for building machine learning model.
#
# 7. Split data into train, test set.
#
# 8. Build Model.
#
# 9. Apply the model.
#
# 10. Evaluate the model.
#
# 11. Finding Optimal K value
#
# 12. Repeat 7, 8, 9 steps.

# %% [markdown]
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Download the dataset here:**
# - https://www.kaggle.com/uciml/iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Question 1
#
# Import the data set and print 10 random rows from the data set
#
# Hint: use **sample()** function to get random rows

# %%
import pandas as pd
iris_df = pd.read_csv('iris.csv')
iris_df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 105  106            7.6           3.0            6.6           2.1
# 111  112            6.4           2.7            5.3           1.9
# 44    45            5.1           3.8            1.9           0.4
# 61    62            5.9           3.0            4.2           1.5
# 120  121            6.9           3.2            5.7           2.3
# 13    14            4.3           3.0            1.1           0.1
# 93    94            5.0           2.3            3.3           1.0
# 19    20            5.1           3.8            1.5           0.3
# 26    27            5.0           3.4            1.6           0.4
# 121  122            5.6           2.8            4.9           2.0
#
#              Species
# 105   Iris-virginica
# 111   Iris-virginica
# 44       Iris-setosa
# 61   Iris-versicolor
# 120   Iris-virginica
# 13       Iris-setosa
# 93   Iris-versicolor
# 19       Iris-setosa
# 26       Iris-setosa
# 121   Iris-virginica

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Question 2 - Estimating missing values
#
# Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median)

# %% [markdown]
# Calculate the number of missing values per column
# - don't use loops

# %%
iris_df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    1
# SepalWidthCm     2
# PetalLengthCm    2
# PetalWidthCm     1
# Species          0
# dtype: int64

# %% [markdown]
# Fill missing values with median of that particular column

# %%
iris_df.fillna(df.median(), inplace=True)

# %% [markdown]
# ### Question 3 - Dealing with categorical data
#
# Change all the classes to numericals (0 to 2)
#
# Hint: use **LabelEncoder()**

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
iris_df['Species'] = le.fit_transform(iris_df['Species'])

# %%
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# ### Question 4
#
# Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.
#
# Hint: use **corr()**

# %%
iris_df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.702734     -0.392693       0.872346
# SepalLengthCm  0.702734       1.000000     -0.109369       0.871120
# SepalWidthCm  -0.392693      -0.109369      1.000000      -0.420713
# PetalLengthCm  0.872346       0.871120     -0.420713       1.000000
# PetalWidthCm   0.890676       0.815986     -0.356510       0.962043
# Species        0.942753       0.775061     -0.417318       0.944477
#
#                PetalWidthCm   Species
# Id                 0.890676  0.942753
# SepalLengthCm      0.815986  0.775061
# SepalWidthCm      -0.356510 -0.417318
# PetalLengthCm      0.962043  0.944477
# PetalWidthCm       1.000000  0.952513
# Species            0.952513  1.000000

# %%
# This is one way
iris_df.loc[:, (iris_df.corr()['Species'] <= -0.1) | (iris_df.corr()['Species'] >= 0.1)].head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
# This is another way
iris_df.loc[:, ~iris_df.corr()['Species'].between(-0.1, 0.1, inclusive=True)].head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# ### Question 5
#
# Observe the independent variables variance and drop such variables having no variance or almost zero variance (variance < 0.1). They will be having almost no influence on the classification
#
# Hint: use **var()**

# %%
iris_df.var()
# Out:
# Id               1938.000000
# SepalLengthCm       0.676645
# SepalWidthCm        0.185552
# PetalLengthCm       3.076516
# PetalWidthCm        0.577141
# Species             0.675322
# dtype: float64

# %%
iris_df.loc[:, iris_df.var() > 0.1].head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# ### Question 6
#
# Plot the scatter matrix for all the variables.
#
# Hint: use **pandas.plotting.scatter_matrix()**
#
# you can also use pairplot()

# %%
pd.plotting.scatter_matrix(iris_df, c=iris_df['Species'], figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FA93E2320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC634668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC665BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC6A5198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC6D3748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC706CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC7432E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC7738D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC773908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC7E3438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC8149E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC848F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC884588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC8B7B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC8F5128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC9256D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC957C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC996278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC9C7828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC9FADD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACA383C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACA67978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACA9BF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACAD8518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACB09AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACB480B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACB78668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACBA8C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACBE9208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACC187B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACC4BD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACC89358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACCB9908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACCEDEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACD294A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FACD5CA58>]],
#       dtype=object)

# %% [markdown]
# ## Split the dataset into training and test sets

# %% [markdown]
# ### Question 7
#
# Split the dataset into training and test sets with 80-20 ratio
#
# Hint: use **train_test_split()**

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Transform data into features and target
X = iris_df.drop(['Species', 'Id'], axis=1) 
y = iris_df['Species']

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (121, 4)
# (121,)

# %% [markdown]
# ### Question 8
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 2, 3, 5, 7, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %%
# loading library
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for k in [2, 3, 5, 7, 9]:
  model = KNeighborsClassifier(n_neighbors = k)    # initialize the model
  model.fit(X_train, y_train)                      # fit the model
  y_pred = model.predict(X_test)                   # make predictions
  print(accuracy_score(y_test, y_pred))            # calculate accuracy
# Out:
# 0.967741935483871
# 0.9354838709677419
# 0.967741935483871
# 0.9354838709677419
# 0.9032258064516129

# %% [markdown]
# ## Find optimal value of K

# %% [markdown]
# ### Question 9 - Finding Optimal value of k
#
# - Run the KNN with no of neighbours to be 1, 3, 5 ... 19
# - Find the **optimal number of neighbours** from the above list

# %%
# empty list that will hold accuracy scores
ac_scores = []

for k in range(1, 20, 2) :
  model = KNeighborsClassifier(n_neighbors = k)    # initialize the model
  model.fit(X_train, y_train)                      # fit the model
  y_pred = model.predict(X_test)                   # make predictions
  score = accuracy_score(y_test, y_pred)           # get accuracy
  ac_scores.append((score, k))                     # append accuracy score
  
# determining best k
print("The max accuracy and optimal number of neighbors is {}".format(max(ac_scores)))
# Out:
# The max accuracy and optimal number of neighbors is (0.967741935483871, 5)

# %% [markdown]
# ### Question 10
#
# Plot accuracy score vs k (with k value on X-axis) using matplotlib.

# %%
import matplotlib.pyplot as plt

score, k = zip(*ac_scores)
plt.plot(k, score)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# # Breast cancer dataset

# %% [markdown]
# ## Read data

# %% [markdown]
# ### Question 1
# Read the data given in bc2.csv file

# %%
# Importing Data file
import pandas as pd
bc_df = pd.read_csv('bc2.csv')
bc_df.head()
# Out:
#         ID  ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0  1000025               5          1           1                  1
# 1  1002945               5          4           4                  5
# 2  1015425               3          1           1                  1
# 3  1016277               6          8           8                  1
# 4  1017023               4          1           1                  3
#
#    Single Epithelial Cell Size Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# 0                            2           1                3                1
# 1                            7          10                3                2
# 2                            2           2                3                1
# 3                            3           4                3                7
# 4                            2           1                3                1
#
#    Mitoses  Class
# 0        1      2
# 1        1      2
# 2        1      2
# 3        1      2
# 4        1      2

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Question 2
# Observe the no.of records in dataset and type of each column

# %%
bc_df.shape
# Out:
# (699, 11)

# %%
bc_df.dtypes
# Out:
# ID                              int64
# ClumpThickness                  int64
# Cell Size                       int64
# Cell Shape                      int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Normal Nucleoli                 int64
# Bland Chromatin                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %% [markdown]
# ### Question 3
# Use summary statistics to check if missing values, outlier and encoding treament is necessary
#
# Hint: use **describe()**

# %%
bc_df.describe().transpose()
# Out:
#                              count          mean            std      min  \
# ID                           699.0  1.071704e+06  617095.729819  61634.0
# ClumpThickness               699.0  4.417740e+00       2.815741      1.0
# Cell Size                    699.0  3.134478e+00       3.051459      1.0
# Cell Shape                   699.0  3.207439e+00       2.971913      1.0
# Marginal Adhesion            699.0  2.806867e+00       2.855379      1.0
# Single Epithelial Cell Size  699.0  3.216023e+00       2.214300      1.0
# Normal Nucleoli              699.0  3.437768e+00       2.438364      1.0
# Bland Chromatin              699.0  2.866953e+00       3.053634      1.0
# Mitoses                      699.0  1.589413e+00       1.715078      1.0
# Class                        699.0  2.689557e+00       0.951273      2.0
#
#                                   25%        50%        75%         max
# ID                           870688.5  1171710.0  1238298.0  13454352.0
# ClumpThickness                    2.0        4.0        6.0        10.0
# Cell Size                         1.0        1.0        5.0        10.0
# Cell Shape                        1.0        1.0        5.0        10.0
# Marginal Adhesion                 1.0        1.0        4.0        10.0
# Single Epithelial Cell Size       2.0        2.0        4.0        10.0
# Normal Nucleoli                   2.0        3.0        5.0        10.0
# Bland Chromatin                   1.0        1.0        4.0        10.0
# Mitoses                           1.0        1.0        1.0        10.0
# Class                             2.0        2.0        4.0         4.0

# %% [markdown]
# #### Check Missing Values

# %%
bc_df.isnull().sum()
# Out:
# ID                             0
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# ### Question 4
# #### Check how many `?` are there in Bare Nuclei feature (they are also unknown or missing values).

# %%
# This is one way
bc_df[bc_df['Bare Nuclei'] == '?'].shape[0]

# This is another way
len(bc_df[bc_df['Bare Nuclei'] == '?'])
# Out:
# 16

# %% [markdown]
# #### Replace them with the 'top' value of the describe function of Bare Nuclei feature
#
# Hint: give value of parameter include='all' in describe function

# %%
bc_df['Bare Nuclei'].replace({'?': bc_df.describe(include='all')['Bare Nuclei']['top']}, inplace=True)

# %% [markdown]
# ### Question 5
# #### Find the distribution of target variable (Class)

# %%
bc_df["Class"].value_counts()
# Out:
# 2    458
# 4    241
# Name: Class, dtype: int64

# %% [markdown]
# #### Plot the distribution of target variable using histogram

# %%
pd.value_counts(bc_df["Class"]).plot(kind="bar")

# %% [markdown]
# #### Convert the datatype of Bare Nuclei to `int`

# %%
bc_df["Bare Nuclei"] = bc_df["Bare Nuclei"].astype("int")

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# ### Question 6
# Plot Scatter Matrix to understand the distribution of variables and check if any variables are collinear and drop one of them.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
pd.plotting.scatter_matrix(bc_df, figsize=(20,20), diagonal="kde")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FADA06048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD6EF2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD71C898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD74AE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD784438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD7B29E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD7E3F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD81B5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD81B5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD88B128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD8BA6D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD8ECC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD92A278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD95B828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD98EDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAEFBD3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAEFED978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF01FF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF05D518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF08DAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF0CD0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF0FE668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF130C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF170208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF19E7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF1D2D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF20E358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF23F908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD4E4A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD472470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD1B26D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAD466E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF274400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF2A39B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF2D8F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF315550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF345B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF3840F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF3B36A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF3E4C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF425240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF4557F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF486DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF4C5390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF4F6940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF52AEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF5664E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF598A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF5D6080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF608630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF638BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF6761D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF6A9780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF6DBD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF718320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF7498D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF77AE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF7B6470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF7E8A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF81CFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF8585C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF88BB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF8C8160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF8FB710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF92BCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF96A2B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF99C860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAF9CEE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFA0B400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFA3B9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFA6EF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFAAB550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFADDB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFB1C0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFB4C6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFB7EC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFBBD240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFBED7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFC20DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFC5F390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFC8F940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFCC1EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFCFF4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFD2FA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFD6F080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB21F048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC5C7278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC589048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC3DE8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAACFF7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC571B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAD24128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB2076D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC3E7C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAFDBB278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB1E2828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB1AFDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB12D3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC484978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC545F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB160518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB132AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC4D10B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB0D7668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAEF8C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAD45208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC4387B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAC4CB518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAD76358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAADA7908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAADDAEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAE164A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAE48A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAE87048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAEB85F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAEE9BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAF67198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAF97748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAAFC9CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB0062E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021FAB036898>]],
#       dtype=object)

# %% [markdown]
# ## Train test split

# %% [markdown]
# ### Question 7
# #### Divide the dataset into feature set and target set

# %%
X = bc_df.drop(["ID", "Class", "Cell Shape"], axis=1)
y = bc_df["Class"]

# %% [markdown]
# #### Divide the Training and Test sets in 70:30

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 10)

# %% [markdown]
# ## Scale the data

# %% [markdown]
# ### Question 8
# Standardize the data
#
# Hint: use **StandardScaler()**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 9
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %%
# loading library
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for k in [3, 5, 9]:
  model = KNeighborsClassifier(n_neighbors = k)    # initialize the model
  model.fit(X_train, y_train)                      # fit the model
  y_pred = model.predict(X_test)                   # make predictions
  print(accuracy_score(y_test, y_pred))            # calculate accuracy
# Out:
# 0.9666666666666667
# 0.9666666666666667
# 0.9619047619047619

# %% [markdown]
# ## Find optimal value of K

# %% [markdown]
# ### Question 10
# Finding Optimal value of k
#
# - Run the KNN with no of neighbours to be 1, 3, 5 ... 19
# - Find the **optimal number of neighbours** from the above list

# %%
# empty list that will hold accuracy scores
ac_scores = []

for k in range(1, 20, 2) :
  model = KNeighborsClassifier(n_neighbors = k)    # initialize the model
  model.fit(X_train, y_train)                      # fit the model
  y_pred = model.predict(X_test)                   # make predictions
  score = accuracy_score(y_test, y_pred)           # get accuracy
  ac_scores.append((score, k))                     # append accuracy score
  
# determining best k
print("The max accuracy and optimal number of neighbors is {}".format(max(ac_scores)))
# Out:
# The max accuracy and optimal number of neighbors is (0.9666666666666667, 19)

# %% [markdown]
# ## Plot accuracy

# %% [markdown]
# ### Question 11
#
# Plot accuracy score vs k (with k value on X-axis) using matplotlib.

# %%
import matplotlib.pyplot as plt

score, k = zip(*ac_scores)
plt.plot(k, score)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Accuracy score')
plt.show()
