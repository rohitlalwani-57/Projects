# %% [markdown]
# # Statistics Project 2 problem statements

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
insurance_df=pd.read_csv("insurance.csv")
insurance_df.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1055   55    male  27.645         0     no  northwest  10594.50155
# 1251   19    male  19.800         0     no  southwest   1241.56500
# 396    43  female  34.400         3     no  southwest   8522.00300
# 938    18    male  26.180         2     no  southeast   2304.00220
# 1315   18    male  28.310         1     no  northeast  11272.33139

# %%
insurance_df.shape
# Out:
# (1338, 7)

# %% [markdown]
# There are 1338 data points with 7 columns.

# %%
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# From the above inference also you can see that there are no missing values in this dataset.

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# describe functions gives the value of all the 5 point summary of numerical attributes for all the features, as shown above. We can also say that the charges shows a large amount of standard deviation as compared to the other variables.

# %%
sns.distplot(insurance_df['bmi']);

# %% [markdown]
# We can see that bmi is having a normal distribution curve as shown above.

# %%
sns.distplot(insurance_df['age']);

# %% [markdown]
# For the age parameter we can see that we have lage data set between the age 20-30 abd 40-50 here. The distibution in this case is not a normal gaussian distribution

# %%
sns.distplot(insurance_df['charges']);

# %% [markdown]
# Charges distribution is also not normal and we can see that most of the datapoints lies between 1000 to 30000 and we have fewer nubers as we move forward.

# %%
insurance_df['bmi'].skew(axis = 0)
# Out:
# 0.2840471105987448

# %%
insurance_df['age'].skew(axis = 0)
# Out:
# 0.05567251565299186

# %%
insurance_df['charges'].skew(axis = 0)
# Out:
# 1.5158796580240388

# %% [markdown]
# From the distribution graphs and also the skewness numbers for each of the columns below are the findings:
# 1. bmi has a positive skew value which means that it has some data points which are very far away from the 3IQR and mean of the datapoints.
# 2. age has a lower value (tending to 0) which means that the distribution of age is almost normal and the skewness is also close to 0. All the datapoints here lies between the IQR range.

# %%
sns.boxplot(x=insurance_df['bmi'])

# %%
sns.boxplot(x=insurance_df['age'])

# %%
sns.boxplot(x=insurance_df['charges'])

# %% [markdown]
# The same conclusion as above from skweness can be drawn after seeing theboxplot, we can see mamy of the datapoints as the outliers in case of bmi and charges , Whereas for age there are no outliers and the distribution is balanced.

# %%
sns.countplot(x="children", data=insurance_df)

# %% [markdown]
# For the categorical features, we can use the countplots to see the distribution of the data points. Children feature has maximum values of 0 and the lowest as 5.

# %%
sns.pairplot(insurance_df, diag_kind='kde')

# %%
sns.barplot(x=insurance_df['smoker'], y=insurance_df['charges'])

# %% [markdown]
# From the above bar graph we can see that all the smokers have significantly high charges that what the non-smokers have.

# %%
sns.barplot(x=insurance_df['sex'], y=insurance_df['bmi'])

# %% [markdown]
#  No the bmi of males do not differ significantly from that of females.

# %%
pd.crosstab(index=insurance_df["smoker"], columns=insurance_df["sex"])
# Out:
# sex     female  male
# smoker
# no         547   517
# yes        115   159

# %% [markdown]
# From the above count we can see that the difference between the male and female smokers are not significantly large.

# %%
Female_df=insurance_df[(insurance_df['sex'] == 'female') & (insurance_df['children'] <3)]
Female_df.head(5)
# Out:
#     age     sex    bmi  children smoker     region      charges
# 0    19  female  27.90         0    yes  southwest  16884.92400
# 5    31  female  25.74         0     no  southeast   3756.62160
# 6    46  female  33.44         1     no  southeast   8240.58960
# 9    60  female  25.84         0     no  northwest  28923.13692
# 11   62  female  26.29         0    yes  southeast  27808.72510

# %%
sns.barplot(x=Female_df['children'], y=Female_df['bmi'])

# %% [markdown]
# From the above we can see that there is no significant difference in the bmi of women with no children or with that of 1  or 2 children
