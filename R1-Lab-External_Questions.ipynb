# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
#Importing Pandas and Numpy.

import pandas as pd
import numpy as np

# %%
#Reading Iris.csv file in a dataframe names Iris.

Iris = pd.read_csv("Iris.csv")
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
#Checking the datatype of all the columns using dtypes.

Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
#Printing top 10 samples from the dataframe Iris using head.

Iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
#Printing bottom 10 samples from the dataframe Iris using tail.

Iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
#Printing sahpe of the dataset using shape on Iris dataframe.

Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
#setting the first column Sepal Length (in cm) as index of the dataframe

Iris.set_index('Sepal Length (in cm)',inplace=False).head()
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
#
#                       Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                   0.2  Iris-setosa
# 4.9                                   0.2  Iris-setosa
# 4.7                                   0.2  Iris-setosa
# 4.6                                   0.2  Iris-setosa
# 5.0                                   0.2  Iris-setosa

# %%
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
#using iloc[] printing all the rows of 3rd column
Iris.iloc[:,3:4]
# Out:
#      Petal width (in cm)
# 0                    0.2
# 1                    0.2
# 2                    0.2
# 3                    0.2
# 4                    0.2
# 5                    0.4
# 6                    0.3
# 7                    0.2
# 8                    0.2
# 9                    0.1
# 10                   0.2
# 11                   0.2
# 12                   0.1
# 13                   0.1
# 14                   0.2
# 15                   0.4
# 16                   0.4
# 17                   0.3
# 18                   0.3
# 19                   0.3
# 20                   0.2
# 21                   0.4
# 22                   0.2
# 23                   0.5
# 24                   0.2
# 25                   0.2
# 26                   0.4
# 27                   0.2
# 28                   0.2
# 29                   0.2
# ..                   ...
# 120                  2.3
# 121                  2.0
# 122                  2.0
# 123                  1.8
# 124                  2.1
# 125                  1.8
# 126                  1.8
# 127                  1.8
# 128                  2.1
# 129                  1.6
# 130                  1.9
# 131                  2.0
# 132                  2.2
# 133                  1.5
# 134                  1.4
# 135                  2.3
# 136                  2.4
# 137                  1.8
# 138                  1.8
# 139                  2.1
# 140                  2.4
# 141                  2.3
# 142                  1.9
# 143                  2.3
# 144                  2.5
# 145                  2.3
# 146                  1.9
# 147                  2.0
# 148                  2.3
# 149                  1.8
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
#First 10 rows of column Sepal Length and Sepal Width using lambda and iloc 
#Iris.iloc[0:10, lambda Iris: [0,1]]

#First 10 rows of column Sepal Length and Sepal Width using iloc 
Iris.iloc[0:10,0:2]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
#Setting index to column class to retrieve all the rows with class name "Iris-setosa"

Iris_1 = pd.read_csv("Iris.csv",index_col = "Class")
Iris_1.loc["Iris-setosa"]
# Out:
#              Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# Class
# Iris-setosa                   5.1                  3.5                   1.4
# Iris-setosa                   4.9                  3.0                   1.4
# Iris-setosa                   4.7                  3.2                   1.3
# Iris-setosa                   4.6                  3.1                   1.5
# Iris-setosa                   5.0                  3.6                   1.4
# Iris-setosa                   5.4                  3.9                   1.7
# Iris-setosa                   4.6                  3.4                   1.4
# Iris-setosa                   5.0                  3.4                   1.5
# Iris-setosa                   4.4                  2.9                   1.4
# Iris-setosa                   4.9                  3.1                   1.5
# Iris-setosa                   5.4                  3.7                   1.5
# Iris-setosa                   4.8                  3.4                   1.6
# Iris-setosa                   4.8                  3.0                   1.4
# Iris-setosa                   4.3                  3.0                   1.1
# Iris-setosa                   5.8                  4.0                   1.2
# Iris-setosa                   5.7                  4.4                   1.5
# Iris-setosa                   5.4                  3.9                   1.3
# Iris-setosa                   5.1                  3.5                   1.4
# Iris-setosa                   5.7                  3.8                   1.7
# Iris-setosa                   5.1                  3.8                   1.5
# Iris-setosa                   5.4                  3.4                   1.7
# Iris-setosa                   5.1                  3.7                   1.5
# Iris-setosa                   4.6                  3.6                   1.0
# Iris-setosa                   5.1                  3.3                   1.7
# Iris-setosa                   4.8                  3.4                   1.9
# Iris-setosa                   5.0                  3.0                   1.6
# Iris-setosa                   5.0                  3.4                   1.6
# Iris-setosa                   5.2                  3.5                   1.5
# Iris-setosa                   5.2                  3.4                   1.4
# Iris-setosa                   4.7                  3.2                   1.6
# Iris-setosa                   4.8                  3.1                   1.6
# Iris-setosa                   5.4                  3.4                   1.5
# Iris-setosa                   5.2                  4.1                   1.5
# Iris-setosa                   5.5                  4.2                   1.4
# Iris-setosa                   4.9                  3.1                   1.5
# Iris-setosa                   5.0                  3.2                   1.2
# Iris-setosa                   5.5                  3.5                   1.3
# Iris-setosa                   4.9                  3.1                   1.5
# Iris-setosa                   4.4                  3.0                   1.3
# Iris-setosa                   5.1                  3.4                   1.5
# Iris-setosa                   5.0                  3.5                   1.3
# Iris-setosa                   4.5                  2.3                   1.3
# Iris-setosa                   4.4                  3.2                   1.3
# Iris-setosa                   5.0                  3.5                   1.6
# Iris-setosa                   5.1                  3.8                   1.9
# Iris-setosa                   4.8                  3.0                   1.4
# Iris-setosa                   5.1                  3.8                   1.6
# Iris-setosa                   4.6                  3.2                   1.4
# Iris-setosa                   5.3                  3.7                   1.5
# Iris-setosa                   5.0                  3.3                   1.4
#
#              Petal width (in cm)
# Class
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.4
# Iris-setosa                  0.3
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.1
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.1
# Iris-setosa                  0.1
# Iris-setosa                  0.2
# Iris-setosa                  0.4
# Iris-setosa                  0.4
# Iris-setosa                  0.3
# Iris-setosa                  0.3
# Iris-setosa                  0.3
# Iris-setosa                  0.2
# Iris-setosa                  0.4
# Iris-setosa                  0.2
# Iris-setosa                  0.5
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.4
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.4
# Iris-setosa                  0.1
# Iris-setosa                  0.2
# Iris-setosa                  0.1
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.1
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.3
# Iris-setosa                  0.3
# Iris-setosa                  0.2
# Iris-setosa                  0.6
# Iris-setosa                  0.4
# Iris-setosa                  0.3
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.2
# Iris-setosa                  0.2

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra'] = Iris['Sepal Length (in cm)'] * Iris['Sepal Width in (cm)']

# %%
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  SepalExtra
# 0                  0.2  Iris-setosa       17.85
# 1                  0.2  Iris-setosa       14.70
# 2                  0.2  Iris-setosa       15.04
# 3                  0.2  Iris-setosa       14.26
# 4                  0.2  Iris-setosa       18.00

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Mean_SLen = Iris['Sepal Length (in cm)'].mean()
Var_SLen = Iris['Sepal Length (in cm)'].var()

print ("Mean and Variance of Sepal Length is {} and {}".format(Mean_SLen, Var_SLen))
# Out:
# Mean and Variance of Sepal Length is 5.843333333333335 and 0.6856935123042505

# %%
Mean_SWid = Iris['Sepal Width in (cm)'].mean()
Var_SWid = Iris['Sepal Width in (cm)'].var()

print ("Mean and Variance of Sepal Width is {} and {}".format(Mean_SWid, Var_SWid))
# Out:
# Mean and Variance of Sepal Width is 3.0540000000000007 and 0.18800402684563763

# %%
Mean_PLen = Iris['Petal length (in cm)'].mean()
Var_PLen = Iris['Petal length (in cm)'].var()

print ("Mean and Variance of Petal Length is {} and {}".format(Mean_PLen, Var_PLen))
# Out:
# Mean and Variance of Petal Length is 3.7586666666666693 and 3.1131794183445156

# %%
Mean_PWid = Iris['Petal width (in cm)'].mean()
Var_PWid = Iris['Petal width (in cm)'].var()

print ("Mean and Variance of Petal Width is {} and {}".format(Mean_PWid, Var_PWid))
# Out:
# Mean and Variance of Petal Width is 1.1986666666666672 and 0.5824143176733784

# %%
Mean_SExt = Iris['SepalExtra'].mean()
Var_SExt = Iris['SepalExtra'].var()

print ("Mean and Variance of Sepal Length is {} and {}".format(Mean_SExt, Var_SExt))
# Out:
# Mean and Variance of Sepal Length is 17.806533333333338 and 11.34808991498881

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def print_num(a,b):
    print (a)
    print (b)
    return

print_num(Iris.iloc[4][0],Iris.iloc[4][1])
# Out:
# 5.0
# 3.6

# %%
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  SepalExtra
# 0                  0.2  Iris-setosa       17.85
# 1                  0.2  Iris-setosa       14.70
# 2                  0.2  Iris-setosa       15.04
# 3                  0.2  Iris-setosa       14.26
# 4                  0.2  Iris-setosa       18.00

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
#Range of column Sepal Length (in cm)

Iris['Sepal Length (in cm)'].max() - Iris['Sepal Length (in cm)'].min()
# Out:
# 3.6000000000000005

# %%
#Range of column Sepal Width in (cm)

Iris['Sepal Width in (cm)'].max() - Iris['Sepal Width in (cm)'].min()
# Out:
# 2.4000000000000004

# %%
#Range of column Petal length (in cm)

Iris['Petal length (in cm)'].max() - Iris['Petal length (in cm)'].min()
# Out:
# 5.9

# %%
#Range of column Petal width (in cm)

Iris['Petal width (in cm)'].max() - Iris['Petal width (in cm)'].min()
# Out:
# 2.4

# %%
#Range of column SepalExtra

Iris['SepalExtra'].max() - Iris['SepalExtra'].min()
# Out:
# 20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
#Sorting the Dataset according to Petal Width

Iris.sort_values('Petal width (in cm)')
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 34                    4.9                  3.1                   1.5
# 0                     5.1                  3.5                   1.4
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# 30                    4.8                  3.1                   1.6
# 33                    5.5                  4.2                   1.4
# 36                    5.5                  3.5                   1.3
# 38                    4.4                  3.0                   1.3
# 39                    5.1                  3.4                   1.5
# 42                    4.4                  3.2                   1.3
# 46                    5.1                  3.8                   1.6
# 47                    4.6                  3.2                   1.4
# 48                    5.3                  3.7                   1.5
# 49                    5.0                  3.3                   1.4
# 25                    5.0                  3.0                   1.6
# 24                    4.8                  3.4                   1.9
# 35                    5.0                  3.2                   1.2
# 3                     4.6                  3.1                   1.5
# 2                     4.7                  3.2                   1.3
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 10                    5.4                  3.7                   1.5
# 4                     5.0                  3.6                   1.4
# 11                    4.8                  3.4                   1.6
# ..                    ...                  ...                   ...
# 111                   6.4                  2.7                   5.3
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 147                   6.5                  3.0                   5.2
# 113                   5.7                  2.5                   5.0
# 131                   7.9                  3.8                   6.4
# 110                   6.5                  3.2                   5.1
# 139                   6.9                  3.1                   5.4
# 102                   7.1                  3.0                   5.9
# 112                   6.8                  3.0                   5.5
# 105                   7.6                  3.0                   6.6
# 124                   6.7                  3.3                   5.7
# 128                   6.4                  2.8                   5.6
# 117                   7.7                  3.8                   6.7
# 132                   6.4                  2.8                   5.6
# 104                   6.5                  3.0                   5.8
# 120                   6.9                  3.2                   5.7
# 115                   6.4                  3.2                   5.3
# 148                   6.2                  3.4                   5.4
# 141                   6.9                  3.1                   5.1
# 143                   6.8                  3.2                   5.9
# 145                   6.7                  3.0                   5.2
# 118                   7.7                  2.6                   6.9
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 140                   6.7                  3.1                   5.6
# 114                   5.8                  2.8                   5.1
# 100                   6.3                  3.3                   6.0
# 144                   6.7                  3.3                   5.7
# 109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class  SepalExtra
# 32                   0.1     Iris-setosa       21.32
# 13                   0.1     Iris-setosa       12.90
# 37                   0.1     Iris-setosa       15.19
# 9                    0.1     Iris-setosa       15.19
# 12                   0.1     Iris-setosa       14.40
# 34                   0.1     Iris-setosa       15.19
# 0                    0.2     Iris-setosa       17.85
# 27                   0.2     Iris-setosa       18.20
# 28                   0.2     Iris-setosa       17.68
# 29                   0.2     Iris-setosa       15.04
# 30                   0.2     Iris-setosa       14.88
# 33                   0.2     Iris-setosa       23.10
# 36                   0.2     Iris-setosa       19.25
# 38                   0.2     Iris-setosa       13.20
# 39                   0.2     Iris-setosa       17.34
# 42                   0.2     Iris-setosa       14.08
# 46                   0.2     Iris-setosa       19.38
# 47                   0.2     Iris-setosa       14.72
# 48                   0.2     Iris-setosa       19.61
# 49                   0.2     Iris-setosa       16.50
# 25                   0.2     Iris-setosa       15.00
# 24                   0.2     Iris-setosa       16.32
# 35                   0.2     Iris-setosa       16.00
# 3                    0.2     Iris-setosa       14.26
# 2                    0.2     Iris-setosa       15.04
# 7                    0.2     Iris-setosa       17.00
# 8                    0.2     Iris-setosa       12.76
# 10                   0.2     Iris-setosa       19.98
# 4                    0.2     Iris-setosa       18.00
# 11                   0.2     Iris-setosa       16.32
# ..                   ...             ...         ...
# 111                  1.9  Iris-virginica       17.28
# 121                  2.0  Iris-virginica       15.68
# 122                  2.0  Iris-virginica       21.56
# 147                  2.0  Iris-virginica       19.50
# 113                  2.0  Iris-virginica       14.25
# 131                  2.0  Iris-virginica       30.02
# 110                  2.0  Iris-virginica       20.80
# 139                  2.1  Iris-virginica       21.39
# 102                  2.1  Iris-virginica       21.30
# 112                  2.1  Iris-virginica       20.40
# 105                  2.1  Iris-virginica       22.80
# 124                  2.1  Iris-virginica       22.11
# 128                  2.1  Iris-virginica       17.92
# 117                  2.2  Iris-virginica       29.26
# 132                  2.2  Iris-virginica       17.92
# 104                  2.2  Iris-virginica       19.50
# 120                  2.3  Iris-virginica       22.08
# 115                  2.3  Iris-virginica       20.48
# 148                  2.3  Iris-virginica       21.08
# 141                  2.3  Iris-virginica       21.39
# 143                  2.3  Iris-virginica       21.76
# 145                  2.3  Iris-virginica       20.10
# 118                  2.3  Iris-virginica       20.02
# 135                  2.3  Iris-virginica       23.10
# 136                  2.4  Iris-virginica       21.42
# 140                  2.4  Iris-virginica       20.77
# 114                  2.4  Iris-virginica       16.24
# 100                  2.5  Iris-virginica       20.79
# 144                  2.5  Iris-virginica       22.11
# 109                  2.5  Iris-virginica       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
#Dropping column SepalExtra from Iris Dataframe

Iris.drop('SepalExtra', axis=1)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
#Creating dataframe IrisSubset from Iris dataframe with first 3 columns using iloc[]

IrisSubset = Iris.iloc[0:10,0:3]

# %%
IrisSubset.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HR = pd.read_csv("HR_external.txt",delimiter="\t")
HR.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
print ("There are {} columns in HR dataset".format(HR.shape[1]))
# Out:
# There are 35 columns in HR dataset

# %%
print ("There are {} rows in HR dataset".format(HR.shape[0]))
# Out:
# There are 1470 rows in HR dataset

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
print (HR.dtypes)
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
HR.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# 11     29               1        153           2                15          2
# 12     31               1        670           2                26          1
# 13     34               1       1346           2                19          2
# 14     28               1        103           2                24          3
# 15     29               1       1389           2                21          4
# 16     32               1        334           2                 5          2
# 17     22               3       1123           2                16          2
# 18     53               1       1219           1                 2          4
# 19     38               1        371           2                 2          3
# 20     24               3        673           2                11          2
# 21     36               1       1218           1                 9          4
# 22     34               1        419           2                 7          4
# 23     21               1        391           2                15          2
# 24     34               1        699           2                 6          1
# 25     53               1       1282           2                 5          3
# 26     32               2       1125           2                16          1
# 27     42               1        691           1                 8          4
# 28     44               1        477           2                 7          4
# 29     46               1        705           1                 2          4
# ...   ...             ...        ...         ...               ...        ...
# 1440   36               2        688           2                 4          2
# 1441   56               3        667           2                 1          4
# 1442   29               1       1092           2                 1          4
# 1443   42               1        300           2                 2          3
# 1444   56               1        310           2                 7          2
# 1445   41               1        582           2                28          4
# 1446   34               1        704           1                28          3
# 1447   36               3        301           1                15          4
# 1448   41               1        930           1                 3          3
# 1449   32               1        529           2                 2          3
# 1450   35               1       1146           3                26          4
# 1451   38               1        345           1                10          2
# 1452   50               2        878           1                 1          4
# 1453   36               1       1120           1                11          4
# 1454   45               1        374           1                20          3
# 1455   40               1       1322           2                 2          4
# 1456   35               2       1199           2                18          4
# 1457   40               1       1194           2                 2          4
# 1458   35               1        287           2                 1          4
# 1459   29               1       1378           2                13          2
# 1460   29               1        468           2                28          4
# 1461   50               1        410           1                28          3
# 1462   39               1        722           1                24          1
# 1463   31               3        325           2                 5          3
# 1464   26               1       1167           1                 5          3
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# 5                  1              1
# 6                  2              1
# 7                  1              1
# 8                  1              1
# 9                  2              1
# 10                 2              1
# 11                 1              1
# 12                 1              1
# 13                 2              1
# 14                 1              1
# 15                 1              1
# 16                 1              1
# 17                 2              1
# 18                 1              1
# 19                 1              1
# 20                 6              1
# 21                 1              1
# 22                 1              1
# 23                 1              1
# 24                 2              1
# 25                 6              1
# 26                 1              1
# 27                 3              1
# 28                 2              1
# 29                 3              1
# ...              ...            ...
# 1440               1              1
# 1441               1              1
# 1442               2              1
# 1443               1              1
# 1444               4              1
# 1445               1              1
# 1446               3              1
# 1447               3              1
# 1448               1              1
# 1449               4              1
# 1450               1              1
# 1451               1              1
# 1452               1              1
# 1453               3              1
# 1454               1              1
# 1455               1              1
# 1456               1              1
# 1457               2              1
# 1458               1              1
# 1459               6              1
# 1460               2              1
# 1461               3              1
# 1462               3              1
# 1463               2              1
# 1464               6              1
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
Number_of_Females = (HR['Gender']==1).sum()

Number_of_Males = (HR['Gender']==2).sum()

print ("There are {} females and {} males in the company" .format(Number_of_Females, Number_of_Males))
# Out:
# There are 882 females and 588 males in the company

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
Quartile_one = HR['Age'].quantile(0.25)
Quartile_three = HR['Age'].quantile(0.75)
IQR = (Quartile_three - Quartile_one)
IQR
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
HR['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
HR['DailyRate'].median()
# Out:
# 802.0

# %%
HR['DailyRate'].var()
# Out:
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel('Atrrition')
plt.ylabel('Individual')
HR['Attrition'].value_counts().plot(kind= 'bar')

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
plt.xlabel('TotalWorkingYears')
plt.ylabel('Individual')
HR['TotalWorkingYears'].value_counts().plot(kind= 'bar')
